# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aneesh Kumar Sagar**<br>
# Current Occupation - Banker<br>
# Desired Occupation - Data Analyst

# %% [markdown]
# *I am interested in data science because i love to find hindden details in data , like puzzle. For me finding something new is
# as good as Invention.*

# %% [markdown]
# ### My code in line 5 is addition of two numbers

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %% [markdown]
# -  Jupiter Notebook
# -  Asset
# -  Watson studio <br>
# 1. Jupiter Notebook
# 1. Asset
# 1. Watson Studio<br>
# __[Hyperlink to IBM](cloud.ibm.com)__
